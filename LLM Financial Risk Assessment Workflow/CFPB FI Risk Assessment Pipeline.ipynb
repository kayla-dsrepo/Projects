# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import glob
import re
import datetime as dt
import ollama
import json
from tqdm import tqdm
import time
import os


# display options
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 
from IPython.display import display
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # CFPB

# %%
df = pd.read_csv("Datasets\CFPB_Complaints.csv")
df.head()
df.shape

df_raw = df
# Out:
#   Date received                                            Product  \
# 0    2020-07-06  Credit reporting, credit repair services, or o...
# 1    2025-10-06  Credit reporting or other personal consumer re...
# 2    2025-10-14  Credit reporting or other personal consumer re...
# 3    2025-10-26  Credit reporting or other personal consumer re...
# 4    2025-10-10  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting  Problem with a company's investigation into an...
# 2  Credit reporting               Incorrect information on your report
# 3  Credit reporting               Incorrect information on your report
# 4  Credit reporting               Incorrect information on your report
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# 1               Investigation took more than 30 days
# 2  Information is missing that should be on the r...
# 3                Information belongs to someone else
# 4                Information belongs to someone else
#
#   Consumer complaint narrative  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   Company State ZIP code Tags  \
# 0     Experian Information Solutions Inc.    FL    346XX  NaN
# 1     Experian Information Solutions Inc.    TX    75454  NaN
# 2                           EQUIFAX, INC.    TX    75062  NaN
# 3  TRANSUNION INTERMEDIATE HOLDINGS, INC.    CA    93619  NaN
# 4                           EQUIFAX, INC.    GA    30341  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                      Other           Web           2020-07-06
# 1                        NaN           Web           2025-10-06
# 2                        NaN           Web           2025-10-14
# 3                        NaN           Web           2025-10-26
# 4                        NaN           Web           2025-10-10
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
# 1                  In progress              Yes                NaN
# 2                  In progress              Yes                NaN
# 3                  In progress              Yes                NaN
# 4                  In progress              Yes                NaN
#
#    Complaint ID
# 0       3730948
# 1      16372503
# 2      16558024
# 3      16826857
# 4      16507707
# (12126091, 18)

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## df_sub

# %%
# subset to the 2024 complaints for selected financial institutions 

# descriptive analysis
df = df_raw


# get available comments
df = df[~df['Consumer complaint narrative'].isna()][~df['Consumer complaint narrative'].isin(['NA','N/A','Not Available',''])]


# narrow down to 2024 data
df['Date received'] = pd.to_datetime(df['Date received'])
df = df[df['Date received']>='2024-01-01']
df.head(2)
df.shape


# subset to specific financial institutions
    # Chase, Bank of America, Wells Fargo, PNC, JPMorgan, Discover, Capital One, Vanguard, and Charles Schwab.

df = df[df['Company'].str.contains(r'Chase|Bank of America|Fargo|PNC|JPMorgan|Discover BANK|Capital One|Vanguard|Schwab',case = False)]


df.head(2)
df.shape
df_sub = df
# Out:
# C:\Users\irene\AppData\Local\Temp\ipykernel_25896\2210883069.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[~df['Consumer complaint narrative'].isna()][~df['Consumer complaint narrative'].isin(['NA','N/A','Not Available',''])]
#    Date received                                            Product  \
# 26    2024-01-05  Credit reporting or other personal consumer re...
# 32    2025-09-29  Credit reporting or other personal consumer re...
#
#          Sub-product                                 Issue  \
# 26  Credit reporting  Incorrect information on your report
# 32  Credit reporting           Improper use of your report
#
#                                         Sub-issue  \
# 26            Information belongs to someone else
# 32  Reporting company used your report improperly
#
#                          Consumer complaint narrative  \
# 26  Kindly address this issue on my credit report....
# 32  I am formally disputing the accuracy of the fo...
#
#                               Company public response  \
# 26  Company has responded to the consumer and the ...
# 32  Company has responded to the consumer and the ...
#
#                                    Company State ZIP code Tags  \
# 26     Experian Information Solutions Inc.    IL    60502  NaN
# 32  TRANSUNION INTERMEDIATE HOLDINGS, INC.    NC    27545  NaN
#
#    Consumer consent provided? Submitted via Date sent to company  \
# 26           Consent provided           Web           2024-01-05
# 32           Consent provided           Web           2025-09-29
#
#        Company response to consumer Timely response? Consumer disputed?  \
# 26  Closed with non-monetary relief              Yes                NaN
# 32          Closed with explanation              Yes                NaN
#
#     Complaint ID
# 26       8113747
# 32      16237002
# (1830636, 18)
#     Date received                                            Product  \
# 39     2025-10-29                        Checking or savings account
# 275    2025-08-15  Credit reporting or other personal consumer re...
#
#           Sub-product                        Issue  \
# 39   Checking account          Managing an account
# 275  Credit reporting  Improper use of your report
#
#                                              Sub-issue  \
# 39                   Problem using a debit or ATM card
# 275  Credit inquiries on your report that you don't...
#
#                           Consumer complaint narrative  \
# 39   On XX/XX/XXXX, a {$890.00} charge was taken fr...
# 275  On XX/XX/scrub>, 2025 I received a text saying...
#
#                                Company public response  \
# 39   Company has responded to the consumer and the ...
# 275                                                NaN
#
#                                Company State ZIP code Tags  \
# 39               WELLS FARGO & COMPANY    AZ    85251  NaN
# 275  CAPITAL ONE FINANCIAL CORPORATION    IN    463XX  NaN
#
#     Consumer consent provided? Submitted via Date sent to company  \
# 39            Consent provided           Web           2025-10-29
# 275           Consent provided           Web           2025-08-15
#
#         Company response to consumer Timely response? Consumer disputed?  \
# 39           Closed with explanation              Yes                NaN
# 275  Closed with non-monetary relief              Yes                NaN
#
#      Complaint ID
# 39       16899880
# 275      15305109
# (80941, 18)

# %% [markdown]
# ## sample complaints

# %%
# sample complaints
df = df_sub

df_f = df[df.Company.str.contains('Bank of America', case=False)] # fidelity Vanguard
df_f.shape
df_f.sample(1)['Consumer complaint narrative'].to_list()
# Out:
# (14269, 18)
# ['I have a problem with Bank of America. They are liars. They are thieves and they are crooks. They will deny a legitimate fraudulent transaction. I filed a dispute for the amount {$970.00} that was fraudulent debited from my account after I came back from my trip in XXXX. I called immediately and the initial rep stated they know and can see that I did not physically use my card. So if I did not physically, use my card and you can check the records how was my card use when I was asleep in my bed that does not make any sense and you guys Bank of America denied my dispute and tell me theyre going to purposely overdraw my account for the credit that they provided me for {$970.00}. That is outrageous. Ive been with Bank of America for almost 20 years. I want this matter solved. This is unreasonable, unfair, and unstable.']

# %% [markdown]
# ## type of products, % dispute, etc.

# %%
df = df_sub


# types of the products

set(df.Product)
set(df['Sub-product'])

# types of the complaints
set(df.Issue)
set(df['Sub-issue'])

# companies
set(df.Company)


# what % gets the timely response of the company

df_t = df.groupby(['Timely response?']).size().reset_index()
df_t=df_t.rename(columns={0:'perct'})
# df_t
df_t['perct'] = df_t['perct']/len(df)*100
df_t


# sample complaints
df.sample(5)['Consumer complaint narrative'].to_list()
# Out:
# {'Checking or savings account',
#  'Credit card',
#  'Credit reporting or other personal consumer reports',
#  'Debt collection',
#  'Debt or credit management',
#  'Money transfer, virtual currency, or money service',
#  'Mortgage',
#  'Payday loan, title loan, personal loan, or advance loan',
#  'Prepaid card',
#  'Student loan',
#  'Vehicle loan or lease'}
# {'Auto debt',
#  'CD (Certificate of Deposit)',
#  'Check cashing service',
#  'Checking account',
#  'Conventional home mortgage',
#  'Credit card debt',
#  'Credit repair services',
#  'Credit reporting',
#  'Debt settlement',
#  'Domestic (US) money transfer',
#  'Earned wage access',
#  'FHA mortgage',
#  'Federal student loan debt',
#  'Federal student loan servicing',
#  'Foreign currency exchange',
#  'General-purpose credit card or charge card',
#  'General-purpose prepaid card',
#  'Gift card',
#  'Government benefit card',
#  'Home equity loan or line of credit (HELOC)',
#  'I do not know',
#  'Installment loan',
#  'International money transfer',
#  'Lease',
#  'Loan',
#  'Manufactured home loan',
#  'Medical debt',
#  'Mobile or digital wallet',
#  "Money order, traveler's check or cashier's check",
#  'Mortgage debt',
#  'Mortgage modification or foreclosure avoidance',
#  'Other advances of future income',
#  'Other banking product or service',
#  'Other debt',
#  'Other personal consumer report',
#  'Other type of mortgage',
#  'Payday loan',
#  'Payday loan debt',
#  'Payroll card',
#  'Personal line of credit',
#  'Private student loan',
#  'Private student loan debt',
#  'Rental debt',
#  'Reverse mortgage',
#  'Savings account',
#  'Store credit card',
#  'Student prepaid card',
#  'Tax refund anticipation loan or check',
#  'Telecommunications debt',
#  'Title loan',
#  'USDA mortgage',
#  'VA mortgage',
#  'Virtual currency'}
# {'Advertising',
#  'Advertising and marketing, including promotional offers',
#  'Applying for a mortgage or refinancing an existing mortgage',
#  'Attempts to collect debt not owed',
#  "Can't contact lender or servicer",
#  "Charged fees or interest you didn't expect",
#  'Charged upfront or unexpected fees',
#  'Closing an account',
#  'Closing on a mortgage',
#  'Closing your account',
#  'Communication tactics',
#  'Confusing or misleading advertising or marketing',
#  'Confusing or missing disclosures',
#  'Credit limit changed',
#  'Credit monitoring or identity theft protection services',
#  'Dealing with your lender or servicer',
#  "Didn't provide services promised",
#  'Electronic communications',
#  'False statements or representation',
#  'Fees or interest',
#  'Fraud or scam',
#  'Getting a credit card',
#  'Getting a line of credit',
#  'Getting a loan',
#  'Getting a loan or lease',
#  'Getting the loan',
#  'Identity theft protection or other monitoring services',
#  'Improper use of your report',
#  'Incorrect exchange rate',
#  'Incorrect information on your report',
#  'Issue where my lender is my school',
#  'Issue with income share agreement',
#  'Issues with repayment',
#  "Loan payment wasn't credited to your account",
#  'Lost or stolen money order',
#  'Managing an account',
#  'Managing the loan or lease',
#  'Managing, opening, or closing your mobile wallet account',
#  'Money was not available when promised',
#  'Opening an account',
#  'Other features, terms, or problems',
#  'Other service problem',
#  'Other transaction problem',
#  'Overdraft, savings, or rewards features',
#  'Problem adding money',
#  'Problem caused by your funds being low',
#  'Problem getting a card or closing an account',
#  'Problem when making payments',
#  "Problem with a company's investigation into an existing issue",
#  "Problem with a company's investigation into an existing problem",
#  'Problem with a lender or other company charging your account',
#  'Problem with a purchase or transfer',
#  'Problem with a purchase shown on your statement',
#  'Problem with additional add-on products or services',
#  'Problem with cash advance',
#  'Problem with customer service',
#  'Problem with fraud alerts or security freezes',
#  'Problem with overdraft',
#  'Problem with the payoff process at the end of the loan',
#  'Problems at the end of the loan or lease',
#  'Problems receiving the advance',
#  "Received a loan you didn't apply for",
#  'Repossession',
#  'Struggling to pay mortgage',
#  'Struggling to pay your bill',
#  'Struggling to pay your loan',
#  'Struggling to repay your loan',
#  'Threatened to contact someone or share information improperly',
#  'Took or threatened to take negative or legal action',
#  'Trouble accessing funds in your mobile or digital wallet',
#  'Trouble during payment process',
#  'Trouble using the card',
#  'Trouble using your card',
#  'Unable to get your credit report or credit score',
#  'Unauthorized transactions or other transaction problem',
#  'Unauthorized withdrawals or charges',
#  'Unexpected fees',
#  'Unexpected or other fees',
#  'Vehicle was repossessed or sold the vehicle',
#  "Was approved for a loan, but didn't receive money",
#  'Written notification about debt',
#  'Wrong amount charged or received'}
# {'Account information incorrect',
#  'Account opened without my consent or knowledge',
#  'Account reinstatement or redemption after repossession',
#  'Account sold or transferred to another company',
#  'Account status incorrect',
#  'Add-on products and services',
#  'An existing modification, forbearance plan, short sale, or other loss mitigation relief',
#  'Application denials',
#  'Application denied',
#  'Applying for or obtaining a modification, forbearance plan, short sale, or deed-in-lieu',
#  'Attempted to collect wrong amount',
#  'Banking errors',
#  'Bankruptcy',
#  'Billing dispute for services',
#  'Billing or statement issues',
#  'Billing problem',
#  'Bounced checks or returned payments',
#  'Called before 8am or after 9pm',
#  "Can't close your account",
#  "Can't get other flexible options for repaying your loan",
#  "Can't stop withdrawals from your account",
#  "Can't temporarily delay making payments",
#  "Can't use card to make purchases",
#  'Cannot graduate, receive diploma, or get transcript due to money owed',
#  "Card company isn't resolving a dispute about a purchase or transfer",
#  'Card opened without my consent or knowledge',
#  'Card was charged for something you did not purchase with the card',
#  'Cashing a check',
#  'Changes in loan terms during or after closing',
#  'Changes in loan terms during the application process',
#  'Changes in terms from what was offered or advertised',
#  'Changes in terms mid-deal or after closing',
#  'Charged for a purchase or transfer you did not make with the card',
#  'Charged too much interest',
#  'Closing disclosure or other related disclosures',
#  'Co-signer',
#  'Collected or attempted to collect exempt funds',
#  'Company closed your account',
#  'Company communicating payment assistance or payment extension options',
#  'Company explaining amount owed',
#  'Confusing or misleading advertising about the card',
#  'Confusing or misleading advertising about the credit card',
#  'Confusing or misleading advertising or marketing',
#  'Confusing or missing disclosures',
#  'Contacted before 8am or after 9pm',
#  'Contacted you after you asked them to stop',
#  'Contacted you instead of your attorney',
#  'Contacted your employer',
#  'Credit card company forcing arbitration',
#  "Credit card company isn't resolving a dispute about a purchase on your statement",
#  "Credit card company won't increase or decrease your credit limit",
#  "Credit card company won't work with you while you're going through financial hardship",
#  'Credit denial',
#  "Credit inquiries on your report that you don't recognize",
#  'Damage caused or loss of personal items in vehicle during the actual repossession',
#  'Debt is not yours',
#  'Debt was already discharged in bankruptcy and is no longer owed',
#  'Debt was paid',
#  'Debt was result of identity theft',
#  'Deficiency balance after repossession',
#  'Delay in processing application',
#  'Delays in the application process',
#  'Delays with the closing process',
#  'Denied loan',
#  'Denied request to lower payments',
#  'Deposits and withdrawals',
#  'Deposits or withdrawals',
#  'Did not receive car title',
#  "Didn't receive advertised or promotional terms",
#  "Didn't receive enough information to verify debt",
#  "Didn't receive notice of right to dispute",
#  "Didn't receive services that were advertised",
#  "Didn't receive terms that were advertised",
#  'Difficulty submitting a dispute or getting information about a dispute over the phone',
#  "Don't agree with the fees charged",
#  "Don't want a card provided by your employer or the government",
#  'Escrow, taxes, or insurance',
#  'Excess mileage, damage, or wear fees, or other problem after the lease is finished',
#  'Fee problem',
#  'Fees charged',
#  'Fees charged for closing account',
#  'Fees or costs after closing',
#  'Fees or costs during the application process',
#  'Filed for bankruptcy',
#  'Foreclosure',
#  'Frequent or repeated calls',
#  'Frequent or repeated messages',
#  'Funds not handled or disbursed as instructed',
#  'Funds not received from closed account',
#  'High pressure sales tactics or recruiting',
#  'High-pressure sales tactics',
#  'Impersonated attorney, law enforcement, or government official',
#  'Indicated you were committing crime by not paying debt',
#  'Information belongs to someone else',
#  'Information is incorrect',
#  'Information is missing that should be on the report',
#  'Information that should be on the report is missing',
#  'Interest rate',
#  'Investigation took more than 30 days',
#  'Late or other fees',
#  'Lender trying to repossess or disable the vehicle',
#  'Lien release',
#  'Loan balance remaining after the vehicle is repossessed and sold',
#  'Loan estimate or other related disclosures',
#  'Loan opened without my consent or knowledge',
#  'Loan sold or transferred to another company',
#  'Money was taken from your account on the wrong day or for the wrong amount',
#  'Need information about your loan balance or loan terms',
#  'Negative impact of inaccurate appraisal',
#  'Non-sufficient funds and associated fees',
#  'Notice to repossess',
#  "Notification didn't disclose it was an attempt to collect a debt",
#  'Old information reappears or never goes away',
#  'Other problem',
#  'Other problem getting your report or credit score',
#  'Overcharged for something you did purchase with the card',
#  'Overdraft charges',
#  'Overdrafts and overdraft fees',
#  'Paying off the loan',
#  'Payment process',
#  'Personal information incorrect',
#  'Privacy issues',
#  'Private mortgage insurance (PMI)',
#  'Problem accessing account',
#  'Problem adding money',
#  'Problem after you declared or threatened to declare bankruptcy',
#  'Problem canceling credit monitoring or identify theft protection service',
#  'Problem during payment process',
#  'Problem getting a working replacement card',
#  'Problem getting your free annual credit report',
#  'Problem lowering your monthly payments',
#  'Problem making or receiving payments',
#  'Problem related to refinancing',
#  'Problem using a debit or ATM card',
#  'Problem using the card to withdraw money from an ATM',
#  'Problem when attempting to purchase vehicle at the end of the lease',
#  'Problem while selling or giving up the vehicle',
#  'Problem with a check written from your prepaid card account',
#  'Problem with a trade-in',
#  'Problem with additional add-on products or services purchased with the loan',
#  'Problem with additional products or services purchased with the loan',
#  'Problem with balance transfer',
#  'Problem with cash advances',
#  'Problem with convenience check',
#  'Problem with customer service',
#  'Problem with direct deposit',
#  'Problem with fees',
#  'Problem with fees charged',
#  'Problem with fees or penalties',
#  'Problem with forgiveness, cancellation, or discharge',
#  'Problem with paying off the loan',
#  'Problem with personal statement of dispute',
#  'Problem with product or service terms changing',
#  'Problem with renewal',
#  'Problem with rewards from credit card',
#  'Problem with signing the paperwork',
#  'Problem with the interest rate',
#  'Problem with your payment plan',
#  'Public record information inaccurate',
#  'Received bad information about your loan',
#  'Received unsolicited financial product or insurance offers after opting out',
#  'Received unwanted marketing or advertising',
#  'Report provided to employer without your written authorization',
#  'Reporting company used your report improperly',
#  'Seized or attempted to seize your property',
#  'Sent card you never applied for',
#  'Setting up an escrow account for taxes and insurance',
#  'Sued you in a state where you do not live or did not sign for the debt',
#  'Sued you without properly notifying you of lawsuit',
#  'Talked to a third-party about your debt',
#  'Termination fees or other problem when ending the lease early',
#  'Their investigation did not fix an error on your report',
#  'Threatened or suggested your credit would be damaged',
#  'Threatened to arrest you or take you to jail if you do not pay',
#  'Threatened to sue you for very old debt',
#  'Threatened to turn you in to immigration or deport you',
#  'Told you not to respond to a lawsuit they filed against you',
#  'Transaction was not authorized',
#  'Trouble closing card',
#  'Trouble getting a working replacement card',
#  'Trouble getting information about the card',
#  'Trouble getting, activating, or registering a card',
#  'Trouble using the card to pay a bill',
#  'Trouble using the card to send money to another person',
#  'Trouble using the card to spend money in a store or online',
#  'Trouble with how payments are being handled',
#  'Trying to communicate with the company to fix an issue related to modification, forbearance, short sale, deed-in-lieu, bankruptcy, or foreclosure',
#  'Trying to communicate with the company to fix an issue while managing or servicing your loan',
#  'Trying to communicate with the company to fix an issue with the application process',
#  'Trying to communicate with the company to fix an issue with the loan closing',
#  'Unable to open an account',
#  'Unable to receive car title or other problem after the loan is paid off',
#  'Unexpected increase in interest rate',
#  'Used obscene, profane, or other abusive language',
#  'Voluntary repossession',
#  'Was not notified of investigation status or results',
#  "Was signed up for overdraft on card, but don't want to be",
#  'You never received your bill or did not know a payment was due',
#  'You told them to stop contacting you, but they keep trying',
#  nan}
# {'BANK OF AMERICA, NATIONAL ASSOCIATION',
#  'CAPITAL ONE FINANCIAL CORPORATION',
#  'CHARLES SCHWAB CORPORATION, THE',
#  'DISCOVER BANK',
#  'JPMORGAN CHASE & CO.',
#  'PNC Bank N.A.',
#  'Vanguard Financial Services, Inc.',
#  'WELLS FARGO & COMPANY'}
#   Timely response?      perct
# 0               No   0.156904
# 1              Yes  99.843096
# ['Please note the above referenced accounts were opened FRAUDULENTLY ; as a result of Identity Theft. My information was compromised & fraudulently used without my permission. My name, social security number, along with fake addresses, emails & phone numbers were also fraudulently used by the fraudster ( s ).',
#  'On approximately XX/XX/XXXX, XXXX XXXX XXXX issued me a credit/refund for ticket XXXX in the amount of {$240.00}. This went to a credit card ending in XXXX. \n\nI dont have a credit card ending in XXXX, but the original purchase was made with one of my Chase credit cards using XXXX XXXX, so I believe the XXXX to be the last four of a temporary virtual card number. \n\nThe refund never posted to my account, so I followed up with XXXX multiple times. On XX/XX/XXXX, they again confirmed the refund went through and this time provided me with an ARN ( Acquirer Reference Number ) that I understand proves that the refund went through. The ARN is XXXX. \n\nI reached out to Chase with this information and they didnt use the ARN to look for the refunded transaction. Instead they simply said we dont see any credits on any of your cards. \n\nI would like Chase to do some actual research using this ARN ( XXXX ) to find out where the refund went and promptly apply a credit of {$240.00} to my account. \n\nI have a case open with XXXX on this, but it seems theyve done everything they can/need to do. \n\nNote : one of the attachments references a second ticket receiving a refund for the same amount of money ( another family member that flew with me ) ; that refund has, in fact, posted to my family members credit card ( a different card issuer, I believe ).',
#  'My bank chase denied my dispute, when i provided them evidence for the dispute, they did no care about looking into my problem, they just dont care. \n\nIm disputing a transaction for the amount of XXXX, a company did work on my car and put incorrect parts on my car not as descrived, i contacted chase to open a dispute and they dont care. Claim number XXXX',
#  'I have been a Chase cardholder for many years. My credit score was close to XXXX, and I paid balances in full or in large installments. I even held a Chase card at about 8 % APR, a rare privilege I earned by being responsible. I had never carried large balances. \n\nEverything changed when my mother was diagnosed with XXXX XXXXXXXX at the beginning of XXXX. I left my business and home to care for her in Florida until she passed away at the end of XXXX. When I returned to XXXX XXXX, I was thrown into a bitter divorce and custody battle that left me {$80000.00} in debt and without the support I had relied on for two decades as a housewife. My income was already devastated when the medical issues began. \n\nWhile in the middle of divorce and custody litigation, I underwent five surgeries in 14 months, including XXXX XXXX XXXX XXXX XXXX that left me sleepless and unable to heal. Just as I was beginning to recover, I was XXXX XXXX XXXX XXXX XXXX XXXX that left me further XXXX Even now, I am only partially able to work. \n\nDuring this entire period, I tried to do the right thing. In early 2024, after my first XXXX, I contacted Chase about my XXXX XXXX ( XXXX ) and Personal Cards ( XXXX and XXXX ). I told them I was struggling but still making minimums and extra payments when I could. I warned them another XXXX XXXX  was coming that would leave me unable to work. I asked for hardship relief : reduced payments, waived fees and interest, or a structured plan. Despite my perfect history, Chase refused, telling me I did not qualify because I had never missed a payment. In other words, they punished me for being proactive and honest. \n\nAs I warned, I defaulted. My credit score collapsed from nearly XXXX to the XXXX. I lost my ~8 % APR card forever. Chase sent my accounts to collections, where I was harassed by agencies like XXXX while still recovering from surgeries, grieving my mother, and raising my child. When I asked Chase to settle, they demanded lump sums with minimal reductions. They even referred me to a third-party hardship agency that charged fees but provided no meaningful relief. \n\nNow I can not secure housing because my credit has been destroyed. I am living on EBT. My entire financial life was ruined while Chase stood by, refused to help, and chose to exploit a loyal customer of nearly two decades.',
#  'XXXX an advertisement on Bass Pro shop website regarding a credit card offer that is not clear especially regarding the five orders which have to be made before you get {$20.00} dollars to apply to your check out order.\n\nafter getting approved and the {$20.00} showing under by profile, you are not notified of the 5 purchases except in an email you receive later. \n\nclearly playing games. i would never have applied for a whopping XXXX dollar credit if i new i had to make 5 purchases. \n\nthe CFPB was created to stop XXXX like this. \n\n\n\ni']

# %% [markdown]
# # Data Sampling

# %%
# get a sample of 250
df = df_sub

df = df.sample(100)

df.to_csv('./Datasets/CFPB_sample.csv',index=False)

# %% [markdown]
# # LLM

# %% [markdown]
# ## parameters - system prompt & model name

# %%
SYSTEM_PROMPT = """You are an expert financial risk analyst. Your task is to score a CFPB consumer complaint based on three criteria: Severity, Complexity, and Actionability. Always output your assessment as a single, valid JSON object.

SCORING CRITERIA (Scale 1 to 5):

1. SEVERITY (1-5): Measures the magnitude of harm or potential harm to the consumer.
   - 1: Minor inconvenience, easily reversible, zero to minimal financial loss (<$100).
   - 5: Catastrophic financial loss (>$10,000), permanent damage to credit/housing, or systemic risk of failure.

2. COMPLEXITY (1-5): Measures the difficulty of investigation and resolution.
   - 1: Simple error (e.g., incorrect fee), clear-cut facts, easily corrected.
   - 5: Legal ambiguity, involves multiple third parties (e.g., collector, servicer, original lender), requires extensive document review, or suggests a novel systemic issue.

3. ACTIONABILITY (1-5): Measures the quality, substance, and utility of the complaint narrative for regulatory action.
   - 1: Low Actionability: Vague, extremely short, contains general accusations but lacks specific dates, dollar amounts, account numbers, or company names. Cannot be acted upon without significant follow-up.
   - 5: High Actionability: Long, detailed narrative (multiple paragraphs), provides sufficient dates, specific dollar amounts, account information, and is written clearly and professionally. Provides sufficient basis for immediate investigation.

Output ONLY a JSON object with the keys 'severity', 'complexity', and 'actionability'.
"""

MODEL_NAME = 'llama3'

OLLAMA_HOST = 'http://localhost:11434' # Default local endpoint

# %% [markdown]
# ## API programming - function

# %%
# Initialize Ollama Client
client = ollama.Client(host=OLLAMA_HOST)


def score_complaint(complaint_text: str, model_name: str = MODEL_NAME):
    """Sends a single complaint to the local Ollama API for structured scoring."""
    
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": f"Score the following complaint: {complaint_text}"}
    ]
    
    try:
        # Call the local Ollama API
        response = client.chat(
            model=model_name,
            messages=messages,
            format="json",  # Forces JSON output from the model
            stream=False,
            # Lower temperature for deterministic, consistent scoring
            options={'num_gpu': 0, 'num_thread': 4, 'temperature': 0.1} 
        )
        
        # The JSON content is returned as a string in the 'content' key
        json_string = response['message']['content']
        scores = json.loads(json_string)
        
        # Basic validation to ensure all required keys are present
        if all(key in scores for key in ['severity', 'complexity', 'actionability']):
            return scores
        else:
            raise ValueError("Missing required keys in JSON output.")
        
    except Exception as e:
        # Log any errors (API connection issue, invalid JSON, key error)
        print(f"Error processing complaint: {e}")
        return {'severity': 0, 'complexity': 0, 'actionability': 0, 'error_detail': str(e)}

# %% [markdown]
# ##  Loop Through All Complaints

# %%
# Read the CSV file
df = pd.read_csv('./Datasets/CFPB_sample.csv')

# Create new columns for the scores
df['severity'] = 0
df['complexity'] = 0
df['actionability'] = 0
df['error_detail'] = None

# Create a directory for batch files if it doesn't exist
batch_dir = './Datasets/batches/'
os.makedirs(batch_dir, exist_ok=True)

# Initialize variables for batch processing
batch_size = 10
batch_number = 1
batch_results = []

print(f"Starting processing of {len(df)} complaints...")
print(f"Saving batches of {batch_size} records to '{batch_dir}'")

# Use tqdm for progress tracking
for index, row in tqdm(df.iterrows(), total=len(df)):
    
    scores = score_complaint(row['Consumer complaint narrative'])
    
    # Store the results, using .get() for safety
    df.loc[index, 'severity'] = scores.get('severity', 0)
    df.loc[index, 'complexity'] = scores.get('complexity', 0)
    df.loc[index, 'actionability'] = scores.get('actionability', 0)
    df.loc[index, 'error_detail'] = scores.get('error_detail', None)
    
    # Add this row to batch results
    batch_results.append({
        'index': index,
        'Complaint ID': row['Complaint ID'],
        'Consumer complaint narrative': row['Consumer complaint narrative'],
        'severity': scores.get('severity', 0),
        'complexity': scores.get('complexity', 0),
        'actionability': scores.get('actionability', 0),
        'error_detail': scores.get('error_detail', None)
    })
    
    # Save batch every 50 records
    if len(batch_results) >= batch_size:
        batch_df = pd.DataFrame(batch_results)
        batch_file = f'{batch_dir}batch_{batch_number:03d}.csv'
        batch_df.to_csv(batch_file, index=False)
        
        print(f"Saved batch {batch_number} to {batch_file}")
        
        # Reset for next batch
        batch_results = []
        batch_number += 1
    
    # Optional: Wait briefly to reduce CPU load/heat
    time.sleep(0.1)

#Save the last batch (if any remaining records)
if batch_results:
    batch_df = pd.DataFrame(batch_results)
    batch_file = f'{batch_dir}batch_{batch_number:03d}.csv'
    batch_df.to_csv(batch_file, index=False)
    print(f"Saved final batch {batch_number} to {batch_file}")

# Now save the complete results
print("\nProcessing complete. Saving final results...")

# Display Results
print("\n--- Final Scored Data Sample ---")
df[['Consumer complaint narrative', 'severity', 'complexity', 'actionability', 'error_detail']].head()

# Save the complete dataset
df.to_csv('./Datasets/Metrics.csv', index=False)
print(f"\nComplete dataset saved to ./Datasets/Metrics.csv")

# Optional: Combine all batch files into one for verification
print("\n--- Batch Files Summary ---")
batch_files = sorted([f for f in os.listdir(batch_dir) if f.endswith('.csv')])
for batch_file in batch_files:
    batch_path = os.path.join(batch_dir, batch_file)
    batch_df = pd.read_csv(batch_path)
    print(f"{batch_file}: {len(batch_df)} records")
# Out:
# Starting processing of 100 complaints...
# Saving batches of 10 records to './Datasets/batches/'
#  10%|█         | 10/100 [05:31<40:05, 26.72s/it]
# Saved batch 1 to ./Datasets/batches/batch_001.csv
#  20%|██        | 20/100 [08:06<22:52, 17.16s/it]
# Saved batch 2 to ./Datasets/batches/batch_002.csv
#  30%|███       | 30/100 [11:04<24:17, 20.83s/it]
# Saved batch 3 to ./Datasets/batches/batch_003.csv
#  40%|████      | 40/100 [15:16<24:00, 24.00s/it]
# Saved batch 4 to ./Datasets/batches/batch_004.csv
#  50%|█████     | 50/100 [18:46<16:22, 19.66s/it]
# Saved batch 5 to ./Datasets/batches/batch_005.csv
#  60%|██████    | 60/100 [21:54<11:47, 17.69s/it]
# Saved batch 6 to ./Datasets/batches/batch_006.csv
#  70%|███████   | 70/100 [24:54<07:32, 15.08s/it]
# Saved batch 7 to ./Datasets/batches/batch_007.csv
#  80%|████████  | 80/100 [28:43<06:31, 19.56s/it]
# Saved batch 8 to ./Datasets/batches/batch_008.csv
#  90%|█████████ | 90/100 [32:23<03:28, 20.88s/it]
# Saved batch 9 to ./Datasets/batches/batch_009.csv
# 100%|██████████| 100/100 [35:50<00:00, 21.50s/it]
# Saved batch 10 to ./Datasets/batches/batch_010.csv
#
# Processing complete. Saving final results...
#
# --- Final Scored Data Sample ---
#                         Consumer complaint narrative  severity  complexity  \
# 0  XXXX XXXX XXXX was hacked and my personal info...         5           4
# 1  On XX/XX/year> I went to a Kohl 's store in XX...         4           3
# 2  On XX/XX/XXXX I deposited a {$25000.00} verifi...         5           4
# 3  I charged ~ {$660.00} on XX/XX/XXXX using my X...         4           3
# 4  A few weeks ago, a friends of mine had clients...         4           3
#
#    actionability error_detail
# 0              5         None
# 1              5         None
# 2              5         None
# 3              5         None
# 4              5         None
# Complete dataset saved to ./Datasets/Metrics.csv
#
# --- Batch Files Summary ---
# batch_001.csv: 10 records
# batch_002.csv: 10 records
# batch_003.csv: 10 records
# batch_004.csv: 10 records
# batch_005.csv: 10 records
# batch_006.csv: 10 records
# batch_007.csv: 10 records
# batch_008.csv: 10 records
# batch_009.csv: 10 records
# batch_010.csv: 10 records

# %% [markdown]
# # Metrics

# %%
df = pd.read_csv('./Datasets/Metrics.csv')
df.head(2)
df.shape
df_0 = df


# check company distribution
df.groupby(['Company']).size().reset_index()
df.groupby(['Product']).size().reset_index()


# by company 
df = df_0


# get % of records by company
df_p =  df.groupby(['Company'])[[ 'Complaint ID']].size().reset_index()
df_p=df_p.rename(columns={0:'perct'})
df_p['perct'] = df_p['perct']/len(df)
df_p['perct'] = df_p['perct']*5 # normalize to 0-5
df_p


# avg severity, complexity, actionability by company & product
df_1 = df.groupby(['Company'])[[ 'severity', 'complexity', 'actionability']].mean().reset_index()
df_1

# avg delayed response by company & product
df['delay'] = df['Timely response?'].apply(lambda x:1 if x=="No" else 0)
df_2 = df.groupby(['Company'])['delay'].mean().reset_index()
df_2

# merge the avg scores
df = df_p.merge(df_1, how = 'left', on = ['Company']).merge(df_2, how = 'left', on = ['Company'])


# final scores: weighted sum 
    # here the delay is assigned a very low weight due to majority of the records got a timely response
    # total weight is 1
df['Final Risk Score'] = 0.3 * df['perct']  +  0.2 * df['severity'] +  0.2 * df['complexity']+  0.2 * df['actionability']+ 0.1 * df['delay']
df['Final Risk Score'] = df['Final Risk Score'].round(2)


df.sort_values(by = 'Final Risk Score',ascending=False)

df.to_csv('./Datasets/ScoreCard_Company Level.csv',index=False)





# by company and product
df = df_0


# get % of records by company
df_p =  df.groupby(['Company','Product'])[[ 'Complaint ID']].size().reset_index()
df_p=df_p.rename(columns={0:'perct'})
df_p['perct'] = df_p['perct']/len(df)
df_p['perct'] = df_p['perct']*5 # normalize to 0-5
df_p


# avg severity, complexity, actionability by company & product
df_1 = df.groupby(['Company','Product'])[[ 'severity', 'complexity', 'actionability']].mean().reset_index()
df_1

# avg delayed response by company & product
df['delay'] = df['Timely response?'].apply(lambda x:1 if x=="No" else 0)
df_2 = df.groupby(['Company','Product'])['delay'].mean().reset_index()
df_2

# merge the avg scores
df = df_p.merge(df_1, how = 'left', on = ['Company','Product']).merge(df_2, how = 'left', on = ['Company','Product'])


# final scores: weighted sum 
    # here the delay is assigned a very low weight due to majority of the records got a timely response
    # total weight is 1
df['Final Risk Score'] = 0.3 * df['perct']  +  0.2 * df['severity'] +  0.2 * df['complexity']+  0.2 * df['actionability']+ 0.1 * df['delay']
df['Final Risk Score'] = df['Final Risk Score'].round(2)



df.sort_values(by = 'Final Risk Score',ascending=False)

df.to_csv('./Datasets/ScoreCard_Company & Product Level.csv',index=False)
# Out:
#   Date received      Product        Sub-product  \
# 0    2024-02-27  Credit card  Store credit card
# 1    2024-06-27  Credit card  Store credit card
#
#                                              Issue  \
# 0                            Getting a credit card
# 1  Problem with a purchase shown on your statement
#
#                                            Sub-issue  \
# 0        Card opened without my consent or knowledge
# 1  Credit card company isn't resolving a dispute ...
#
#                         Consumer complaint narrative Company public response  \
# 0  XXXX XXXX XXXX was hacked and my personal info...                     NaN
# 1  On XX/XX/year> I went to a Kohl 's store in XX...                     NaN
#
#                              Company State ZIP code  ... Submitted via  \
# 0  CAPITAL ONE FINANCIAL CORPORATION    NC    28152  ...           Web
# 1  CAPITAL ONE FINANCIAL CORPORATION    ID    83713  ...           Web
#
#   Date sent to company Company response to consumer Timely response?  \
# 0           2024-02-27      Closed with explanation              Yes
# 1           2024-06-27      Closed with explanation              Yes
#
#   Consumer disputed? Complaint ID  severity  complexity  actionability  \
# 0                NaN      8423056         5           4              5
# 1                NaN      9359274         4           3              5
#
#    error_detail
# 0           NaN
# 1           NaN
#
# [2 rows x 22 columns]
# (100, 22)
#                                  Company   0
# 0  BANK OF AMERICA, NATIONAL ASSOCIATION  17
# 1      CAPITAL ONE FINANCIAL CORPORATION  42
# 2                          DISCOVER BANK   8
# 3                   JPMORGAN CHASE & CO.  21
# 4                          PNC Bank N.A.   1
# 5                  WELLS FARGO & COMPANY  11
#                                              Product   0
# 0                        Checking or savings account  29
# 1                                        Credit card  35
# 2  Credit reporting or other personal consumer re...  24
# 3                                    Debt collection   4
# 4  Money transfer, virtual currency, or money ser...   4
# 5                                           Mortgage   1
# 6                                       Student loan   1
# 7                              Vehicle loan or lease   2
#                                  Company  perct
# 0  BANK OF AMERICA, NATIONAL ASSOCIATION   0.85
# 1      CAPITAL ONE FINANCIAL CORPORATION   2.10
# 2                          DISCOVER BANK   0.40
# 3                   JPMORGAN CHASE & CO.   1.05
# 4                          PNC Bank N.A.   0.05
# 5                  WELLS FARGO & COMPANY   0.55
#                                  Company  severity  complexity  actionability
# 0  BANK OF AMERICA, NATIONAL ASSOCIATION  3.823529    3.176471       4.470588
# 1      CAPITAL ONE FINANCIAL CORPORATION  3.476190    3.261905       4.642857
# 2                          DISCOVER BANK  4.000000    3.375000       4.875000
# 3                   JPMORGAN CHASE & CO.  3.904762    3.190476       4.761905
# 4                          PNC Bank N.A.  4.000000    3.000000       5.000000
# 5                  WELLS FARGO & COMPANY  4.090909    3.727273       5.000000
#                                  Company  delay
# 0  BANK OF AMERICA, NATIONAL ASSOCIATION    0.0
# 1      CAPITAL ONE FINANCIAL CORPORATION    0.0
# 2                          DISCOVER BANK    0.0
# 3                   JPMORGAN CHASE & CO.    0.0
# 4                          PNC Bank N.A.    0.0
# 5                  WELLS FARGO & COMPANY    0.0
#                                  Company  perct  severity  complexity  \
# 1      CAPITAL ONE FINANCIAL CORPORATION   2.10  3.476190    3.261905
# 5                  WELLS FARGO & COMPANY   0.55  4.090909    3.727273
# 3                   JPMORGAN CHASE & CO.   1.05  3.904762    3.190476
# 2                          DISCOVER BANK   0.40  4.000000    3.375000
# 0  BANK OF AMERICA, NATIONAL ASSOCIATION   0.85  3.823529    3.176471
# 4                          PNC Bank N.A.   0.05  4.000000    3.000000
#
#    actionability  delay  Final Risk Score
# 1       4.642857    0.0              2.91
# 5       5.000000    0.0              2.73
# 3       4.761905    0.0              2.69
# 2       4.875000    0.0              2.57
# 0       4.470588    0.0              2.55
# 4       5.000000    0.0              2.42
#                                   Company  \
# 0   BANK OF AMERICA, NATIONAL ASSOCIATION
# 1   BANK OF AMERICA, NATIONAL ASSOCIATION
# 2   BANK OF AMERICA, NATIONAL ASSOCIATION
# 3   BANK OF AMERICA, NATIONAL ASSOCIATION
# 4       CAPITAL ONE FINANCIAL CORPORATION
# 5       CAPITAL ONE FINANCIAL CORPORATION
# 6       CAPITAL ONE FINANCIAL CORPORATION
# 7       CAPITAL ONE FINANCIAL CORPORATION
# 8       CAPITAL ONE FINANCIAL CORPORATION
# 9       CAPITAL ONE FINANCIAL CORPORATION
# 10                          DISCOVER BANK
# 11                          DISCOVER BANK
# 12                          DISCOVER BANK
# 13                          DISCOVER BANK
# 14                   JPMORGAN CHASE & CO.
# 15                   JPMORGAN CHASE & CO.
# 16                   JPMORGAN CHASE & CO.
# 17                   JPMORGAN CHASE & CO.
# 18                          PNC Bank N.A.
# 19                  WELLS FARGO & COMPANY
# 20                  WELLS FARGO & COMPANY
# 21                  WELLS FARGO & COMPANY
# 22                  WELLS FARGO & COMPANY
#
#                                               Product  perct
# 0                         Checking or savings account   0.35
# 1                                         Credit card   0.35
# 2   Credit reporting or other personal consumer re...   0.05
# 3   Money transfer, virtual currency, or money ser...   0.10
# 4                         Checking or savings account   0.40
# 5                                         Credit card   0.70
# 6   Credit reporting or other personal consumer re...   0.80
# 7                                     Debt collection   0.05
# 8   Money transfer, virtual currency, or money ser...   0.05
# 9                               Vehicle loan or lease   0.10
# 10                                        Credit card   0.15
# 11  Credit reporting or other personal consumer re...   0.10
# 12                                    Debt collection   0.10
# 13                                       Student loan   0.05
# 14                        Checking or savings account   0.55
# 15                                        Credit card   0.40
# 16  Money transfer, virtual currency, or money ser...   0.05
# 17                                           Mortgage   0.05
# 18                        Checking or savings account   0.05
# 19                        Checking or savings account   0.10
# 20                                        Credit card   0.15
# 21  Credit reporting or other personal consumer re...   0.25
# 22                                    Debt collection   0.05
#                                   Company  \
# 0   BANK OF AMERICA, NATIONAL ASSOCIATION
# 1   BANK OF AMERICA, NATIONAL ASSOCIATION
# 2   BANK OF AMERICA, NATIONAL ASSOCIATION
# 3   BANK OF AMERICA, NATIONAL ASSOCIATION
# 4       CAPITAL ONE FINANCIAL CORPORATION
# 5       CAPITAL ONE FINANCIAL CORPORATION
# 6       CAPITAL ONE FINANCIAL CORPORATION
# 7       CAPITAL ONE FINANCIAL CORPORATION
# 8       CAPITAL ONE FINANCIAL CORPORATION
# 9       CAPITAL ONE FINANCIAL CORPORATION
# 10                          DISCOVER BANK
# 11                          DISCOVER BANK
# 12                          DISCOVER BANK
# 13                          DISCOVER BANK
# 14                   JPMORGAN CHASE & CO.
# 15                   JPMORGAN CHASE & CO.
# 16                   JPMORGAN CHASE & CO.
# 17                   JPMORGAN CHASE & CO.
# 18                          PNC Bank N.A.
# 19                  WELLS FARGO & COMPANY
# 20                  WELLS FARGO & COMPANY
# 21                  WELLS FARGO & COMPANY
# 22                  WELLS FARGO & COMPANY
#
#                                               Product  severity  complexity  \
# 0                         Checking or savings account  4.142857    3.142857
# 1                                         Credit card  3.714286    3.571429
# 2   Credit reporting or other personal consumer re...  3.000000    2.000000
# 3   Money transfer, virtual currency, or money ser...  3.500000    2.500000
# 4                         Checking or savings account  3.500000    3.500000
# 5                                         Credit card  3.642857    3.214286
# 6   Credit reporting or other personal consumer re...  3.312500    3.312500
# 7                                     Debt collection  4.000000    3.000000
# 8   Money transfer, virtual currency, or money ser...  5.000000    4.000000
# 9                               Vehicle loan or lease  2.500000    2.000000
# 10                                        Credit card  3.666667    3.333333
# 11  Credit reporting or other personal consumer re...  3.500000    3.500000
# 12                                    Debt collection  5.000000    3.500000
# 13                                       Student loan  4.000000    3.000000
# 14                        Checking or savings account  4.000000    3.363636
# 15                                        Credit card  4.000000    3.250000
# 16  Money transfer, virtual currency, or money ser...  2.000000    1.000000
# 17                                           Mortgage  4.000000    3.000000
# 18                        Checking or savings account  4.000000    3.000000
# 19                        Checking or savings account  4.000000    4.000000
# 20                                        Credit card  4.333333    4.000000
# 21  Credit reporting or other personal consumer re...  4.000000    3.600000
# 22                                    Debt collection  4.000000    3.000000
#
#     actionability
# 0        4.857143
# 1        4.285714
# 2        2.000000
# 3        5.000000
# 4        4.875000
# 5        4.785714
# 6        4.812500
# 7        2.000000
# 8        5.000000
# 9        2.500000
# 10       4.666667
# 11       5.000000
# 12       5.000000
# 13       5.000000
# 14       4.818182
# 15       4.875000
# 16       3.000000
# 17       5.000000
# 18       5.000000
# 19       5.000000
# 20       5.000000
# 21       5.000000
# 22       5.000000
#                                   Company  \
# 0   BANK OF AMERICA, NATIONAL ASSOCIATION
# 1   BANK OF AMERICA, NATIONAL ASSOCIATION
# 2   BANK OF AMERICA, NATIONAL ASSOCIATION
# 3   BANK OF AMERICA, NATIONAL ASSOCIATION
# 4       CAPITAL ONE FINANCIAL CORPORATION
# 5       CAPITAL ONE FINANCIAL CORPORATION
# 6       CAPITAL ONE FINANCIAL CORPORATION
# 7       CAPITAL ONE FINANCIAL CORPORATION
# 8       CAPITAL ONE FINANCIAL CORPORATION
# 9       CAPITAL ONE FINANCIAL CORPORATION
# 10                          DISCOVER BANK
# 11                          DISCOVER BANK
# 12                          DISCOVER BANK
# 13                          DISCOVER BANK
# 14                   JPMORGAN CHASE & CO.
# 15                   JPMORGAN CHASE & CO.
# 16                   JPMORGAN CHASE & CO.
# 17                   JPMORGAN CHASE & CO.
# 18                          PNC Bank N.A.
# 19                  WELLS FARGO & COMPANY
# 20                  WELLS FARGO & COMPANY
# 21                  WELLS FARGO & COMPANY
# 22                  WELLS FARGO & COMPANY
#
#                                               Product  delay
# 0                         Checking or savings account    0.0
# 1                                         Credit card    0.0
# 2   Credit reporting or other personal consumer re...    0.0
# 3   Money transfer, virtual currency, or money ser...    0.0
# 4                         Checking or savings account    0.0
# 5                                         Credit card    0.0
# 6   Credit reporting or other personal consumer re...    0.0
# 7                                     Debt collection    0.0
# 8   Money transfer, virtual currency, or money ser...    0.0
# 9                               Vehicle loan or lease    0.0
# 10                                        Credit card    0.0
# 11  Credit reporting or other personal consumer re...    0.0
# 12                                    Debt collection    0.0
# 13                                       Student loan    0.0
# 14                        Checking or savings account    0.0
# 15                                        Credit card    0.0
# 16  Money transfer, virtual currency, or money ser...    0.0
# 17                                           Mortgage    0.0
# 18                        Checking or savings account    0.0
# 19                        Checking or savings account    0.0
# 20                                        Credit card    0.0
# 21  Credit reporting or other personal consumer re...    0.0
# 22                                    Debt collection    0.0
#                                   Company  \
# 8       CAPITAL ONE FINANCIAL CORPORATION
# 12                          DISCOVER BANK
# 20                  WELLS FARGO & COMPANY
# 19                  WELLS FARGO & COMPANY
# 21                  WELLS FARGO & COMPANY
# 14                   JPMORGAN CHASE & CO.
# 5       CAPITAL ONE FINANCIAL CORPORATION
# 15                   JPMORGAN CHASE & CO.
# 0   BANK OF AMERICA, NATIONAL ASSOCIATION
# 6       CAPITAL ONE FINANCIAL CORPORATION
# 4       CAPITAL ONE FINANCIAL CORPORATION
# 11                          DISCOVER BANK
# 1   BANK OF AMERICA, NATIONAL ASSOCIATION
# 13                          DISCOVER BANK
# 17                   JPMORGAN CHASE & CO.
# 18                          PNC Bank N.A.
# 22                  WELLS FARGO & COMPANY
# 10                          DISCOVER BANK
# 3   BANK OF AMERICA, NATIONAL ASSOCIATION
# 7       CAPITAL ONE FINANCIAL CORPORATION
# 9       CAPITAL ONE FINANCIAL CORPORATION
# 2   BANK OF AMERICA, NATIONAL ASSOCIATION
# 16                   JPMORGAN CHASE & CO.
#
#                                               Product  perct  severity  \
# 8   Money transfer, virtual currency, or money ser...   0.05  5.000000
# 12                                    Debt collection   0.10  5.000000
# 20                                        Credit card   0.15  4.333333
# 19                        Checking or savings account   0.10  4.000000
# 21  Credit reporting or other personal consumer re...   0.25  4.000000
# 14                        Checking or savings account   0.55  4.000000
# 5                                         Credit card   0.70  3.642857
# 15                                        Credit card   0.40  4.000000
# 0                         Checking or savings account   0.35  4.142857
# 6   Credit reporting or other personal consumer re...   0.80  3.312500
# 4                         Checking or savings account   0.40  3.500000
# 11  Credit reporting or other personal consumer re...   0.10  3.500000
# 1                                         Credit card   0.35  3.714286
# 13                                       Student loan   0.05  4.000000
# 17                                           Mortgage   0.05  4.000000
# 18                        Checking or savings account   0.05  4.000000
# 22                                    Debt collection   0.05  4.000000
# 10                                        Credit card   0.15  3.666667
# 3   Money transfer, virtual currency, or money ser...   0.10  3.500000
# 7                                     Debt collection   0.05  4.000000
# 9                               Vehicle loan or lease   0.10  2.500000
# 2   Credit reporting or other personal consumer re...   0.05  3.000000
# 16  Money transfer, virtual currency, or money ser...   0.05  2.000000
#
#     complexity  actionability  delay  Final Risk Score
# 8     4.000000       5.000000    0.0              2.82
# 12    3.500000       5.000000    0.0              2.73
# 20    4.000000       5.000000    0.0              2.71
# 19    4.000000       5.000000    0.0              2.63
# 21    3.600000       5.000000    0.0              2.60
# 14    3.363636       4.818182    0.0              2.60
# 5     3.214286       4.785714    0.0              2.54
# 15    3.250000       4.875000    0.0              2.54
# 0     3.142857       4.857143    0.0              2.53
# 6     3.312500       4.812500    0.0              2.53
# 4     3.500000       4.875000    0.0              2.50
# 11    3.500000       5.000000    0.0              2.43
# 1     3.571429       4.285714    0.0              2.42
# 13    3.000000       5.000000    0.0              2.42
# 17    3.000000       5.000000    0.0              2.42
# 18    3.000000       5.000000    0.0              2.42
# 22    3.000000       5.000000    0.0              2.42
# 10    3.333333       4.666667    0.0              2.38
# 3     2.500000       5.000000    0.0              2.23
# 7     3.000000       2.000000    0.0              1.82
# 9     2.000000       2.500000    0.0              1.43
# 2     2.000000       2.000000    0.0              1.42
# 16    1.000000       3.000000    0.0              1.22
